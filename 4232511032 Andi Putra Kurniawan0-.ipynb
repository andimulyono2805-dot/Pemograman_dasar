# %% [markdown]
# <a href="https://colab.research.google.com/github/andimulyono2805-dot/Pemograman_dasar/blob/main/4232511032%20Andi%20Putra%20Kurniawan0-.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

Nama = "Andi"
Umur = 21
Jurusan = "RPE"
Semester = 3
Matakuliah = 'pemerograman Dasar'
Status_lulus = False

print(Nama)
print(Umur)
print(Jurusan)
print(Semester)
print(Matakuliah)
print(Status_lulus)
# Out:
# Andi
# 21
# RPE
# 3
# pemerograman Dasar
# False
